# %%
# !pip install seaborn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 kB 7.0 MB/s eta 0:00:0000:01
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
df = pd.read_csv('initial_df.csv')

# %%
Rel = df.Relativity

# %%
Rel.plot()
# Out:
# <AxesSubplot: >

# %%
counts = Rel.value_counts()

# %%
sns.displot(data=df["Relativity"], kde=True)

# %%
# !pip install scipy
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
from scipy.stats import truncnorm
def get_truncated_normal(mean=0, sd=1, low=0, upp=10):
    return truncnorm(
        (low - mean) / sd, (upp - mean) / sd, loc=mean, scale=sd)

# %%
X = get_truncated_normal(mean=40, sd=20, low=18, upp=80)

# %%
a = X.rvs(size = 1)

# %%
int(a)
# Out:
# 60

# %%
b = int(get_truncated_normal(mean=40, sd=20, low=18, upp=80).rvs())

# %%
b
# Out:
# 26

# %%
def get_age_relativity(age_dict):
    relativity = 1
    random_age = int(get_truncated_normal(mean=40, sd=20, low=18, upp=80).rvs())
    if 18 <= random_age < 25:
        relativity = age_dict["18-24 years"]
    elif 25 <= random_age <= 45:
        relativity = age_dict["25-45 years"]
    elif 45 < random_age <= 60:
        relativity = age_dict["45-60 years"]
    elif 60 < random_age:
        relativity = age_dict["60+ years"]

    return relativity

# %%
age = {"18-24 years": 1.2, "25-45 years": 1, "45-60 years": 1.15,
           "60+ years": 1.25}

# %%
r = get_age_relativity(age)

# %%
r
# Out:
# 1.25

# %%
from scipy.stats import skewnorm
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1)

# %%
a = 10
x = np.linspace(skewnorm.ppf(300, a),
                skewnorm.ppf(850, a), 100)

# %%
ax.plot(x, skewnorm.pdf(x, a),
       'r-', lw=5, alpha=0.6, label='skewnorm pdf')

# %%
skewnorm.rvs(a)
# Out:
# 1.2502612572335887

# %%
a=10
data= skewnorm.rvs(a, size=10)

# %%
data
# Out:
# array([0.60296593, 0.19068396, 0.49880588, 0.17126154, 1.137491  ,
#        0.33425954, 0.54600291, 0.90145295, 0.27570034, 0.60264554])

# %%
def get_credit_relativity(credit_dict):
    relativity = 1
    random_credit = int(get_truncated_normal(mean=700, sd=100, low=350, upp=850).rvs())
    if 300 <= random_credit < 580:
        relativity = credit_dict["300-579"]
    elif 580 <= random_credit < 670 :
        relativity = credit_dict["580-669"]
    elif 670 <= random_credit < 740:
        relativity = credit_dict["670-739"]
    elif 740 <= random_credit < 800:
        relativity = credit_dict["740-799"]
    elif 800 <= random_credit:
        relativity = credit_dict["800-850"]
    print(random_credit)
    return relativity

# %%
credit = {"300-579": 1.2, "580-669": 1.1, "670-739": 1,
                    "740-799": 0.95, "800-850": 0.88}

# %%
credit1 = get_credit_relativity(credit)
# Out:
# 740

# %%
credit1
# Out:
# 0.95

# %%
age = {"18-24 years": 1.2, "25-45 years": 1, "45-60 years": 1.15,
           "60+ years": 1.25}
driving_hist_dui = {"No": 1, "Yes": 1.2}
driving_hist_reckless = {"No": 1, "Yes": 1.1}
driving_hist_speeding = {"No": 1, "Yes": 1.05}
credit_score = {"300-579": 1.2, "580-669": 1.1, "670-739": 1,
                    "740-799": 0.95, "800-850": 0.88}
driving_exp = {"less than 1 year": 1.1, "1-5 years": 1.05,
                   "6-15 years": 1, "15+ years": 0.97}
location = {"Urban": 1.05, "Rural": 0.97, "Suburban": 1}
insurance_hist = {"No coverage": 1.2, "Coverage (past 6 months)": 1.05,
                      "Coverage (past 1 year)": 1.05}
annual_mileage = {"0-7500 miles": 1, "7500-10000 miles": 1.1,
                      "10001-15000 miles": 1.15, "15000+ miles": 1.2}
marital_status = {"Married": 0.95, "Single/Divorced/Widowed": 1}
claims_hist = {"Filed within last 1 year": 1.25, "Filed within last 1-3 years": 1.15,
                   "No claims filed": 1}
coverage_level = {"10-20k": 0.94, "20k-30k": 0.97, "30k-40k": 1, "40k-50k": 1.05,
                      "50-60k": 1.09, "60k-70k": 1.12, "70k-80k": 1.15, "80k-90k": 1.18,
                      "90k-100k": 1.22, "100k-110k": 1.25, "110-120k": 1.28, "120k-130k": 1.32,
                      "130k-140k": 1.35, "140k-150k": 1.38}
deductible = {"No deductible": 1.2, "$250": 1, "$500": 0.9, "$1000": 0.8}
vehicle_safety = {"0 NCAP": 1.15, "1 NCAP": 1.1, "2 NCAP": 1.05, "3 NCAP": 1,
                      "4 NCAP": 0.95, "5 NCAP": 0.9}
information_dict = {'age':age, 'driving_hist_dui':driving_hist_dui,'driving_hist_reckless': driving_hist_reckless, 'driving_hist_speeding': driving_hist_speeding, 'credit_score': credit_score,'driving_exp': driving_exp, 'location': location, 'insurance_hist': insurance_hist, 'annual_mileage': annual_mileage, 'marital_status': marital_status,'claims_hist' : claims_hist,'coverage_level':coverage_level, 'deductible':deductible, 'vehicle_safety':vehicle_safety}
information_dict
# Out:
# {'age': {'18-24 years': 1.2,
#   '25-45 years': 1,
#   '45-60 years': 1.15,
#   '60+ years': 1.25},
#  'driving_hist_dui': {'No': 1, 'Yes': 1.2},
#  'driving_hist_reckless': {'No': 1, 'Yes': 1.1},
#  'driving_hist_speeding': {'No': 1, 'Yes': 1.05},
#  'credit_score': {'300-579': 1.2,
#   '580-669': 1.1,
#   '670-739': 1,
#   '740-799': 0.95,
#   '800-850': 0.88},
#  'driving_exp': {'less than 1 year': 1.1,
#   '1-5 years': 1.05,
#   '6-15 years': 1,
#   '15+ years': 0.97},
#  'location': {'Urban': 1.05, 'Rural': 0.97, 'Suburban': 1},
#  'insurance_hist': {'No coverage': 1.2,
#   'Coverage (past 6 months)': 1.05,
#   'Coverage (past 1 year)': 1.05},
#  'annual_mileage': {'0-7500 miles': 1,
#   '7500-10000 miles': 1.1,
#   '10001-15000 miles': 1.15,
#   '15000+ miles': 1.2},
#  'marital_status': {'Married': 0.95, 'Single/Divorced/Widowed': 1},
#  'claims_hist': {'Filed within last 1 year': 1.25,
#   'Filed within last 1-3 years': 1.15,
#   'No claims filed': 1},
# ...

# %%
age
# Out:
# {'18-24 years': 1.2, '25-45 years': 1, '45-60 years': 1.15, '60+ years': 1.25}

# %%
#x = np.random.randint(0, len(credit))
value = list(credit.values())[np.random.randint(0, len(credit))]
value
# Out:
# 0.95

# %%
val =     v = {'18-24 years': 0, '25-45 years': 0, '45-60 years': 0, '60+ years': 0}
def get_general_relativity(val_dict, agg_dict, variable):
    """
    Finds random relativity of varibales not associated with any distribution
    :return: relativity
    """
    d = val_dict[variable]
    x = np.random.randint(0, len(d))
    print(d)
    relativity = list(d.values())[x]
    key = list(d.keys())[list(d.values()).index(relativity)]
    val[key] += 1
    print(key)
    print(val)
    return relativity

# %%
get_general_relativity(information_dict, 'age', val)

# %%
age

# %%
list(age.keys())[3]

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.keys())[3]

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
s = '25k'

# %%
s[:-1]

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
s[:-1]
# Out:
# '25'

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict

# %%
information_dict

# %%
list(age.values()).index(1.25)
# Out:
# 3

# %%
import copy
agg_dict = copy.deepcopy(information_dict)
for key in agg_dict:
    for k in agg_dict[key]:
        agg_dict[key][k] = 0

# %%
agg_dict
# Out:
# {'age': {'18-24 years': 0, '25-45 years': 0, '45-60 years': 0, '60+ years': 0},
#  'driving_hist_dui': {'No': 0, 'Yes': 0},
#  'driving_hist_reckless': {'No': 0, 'Yes': 0},
#  'driving_hist_speeding': {'No': 0, 'Yes': 0},
#  'credit_score': {'300-579': 0,
#   '580-669': 0,
#   '670-739': 0,
#   '740-799': 0,
#   '800-850': 0},
#  'driving_exp': {'less than 1 year': 0,
#   '1-5 years': 0,
#   '6-15 years': 0,
#   '15+ years': 0},
#  'location': {'Urban': 0, 'Rural': 0, 'Suburban': 0},
#  'insurance_hist': {'No coverage': 0,
#   'Coverage (past 6 months)': 0,
#   'Coverage (past 1 year)': 0},
#  'annual_mileage': {'0-7500 miles': 0,
#   '7500-10000 miles': 0,
#   '10001-15000 miles': 0,
#   '15000+ miles': 0},
#  'marital_status': {'Married': 0, 'Single/Divorced/Widowed': 0},
#  'claims_hist': {'Filed within last 1 year': 0,
#   'Filed within last 1-3 years': 0,
#   'No claims filed': 0},
#  'coverage_level': {'10-20k': 0,
#   '20k-30k': 0,
#   '30k-40k': 0,
#   '40k-50k': 0,
# ...

# %%
information_dict
# Out:
# {'age': {'18-24 years': 1.2,
#   '25-45 years': 1,
#   '45-60 years': 1.15,
#   '60+ years': 1.25},
#  'driving_hist_dui': {'No': 1, 'Yes': 1.2},
#  'driving_hist_reckless': {'No': 1, 'Yes': 1.1},
#  'driving_hist_speeding': {'No': 1, 'Yes': 1.05},
#  'credit_score': {'300-579': 1.2,
#   '580-669': 1.1,
#   '670-739': 1,
#   '740-799': 0.95,
#   '800-850': 0.88},
#  'driving_exp': {'less than 1 year': 1.1,
#   '1-5 years': 1.05,
#   '6-15 years': 1,
#   '15+ years': 0.97},
#  'location': {'Urban': 1.05, 'Rural': 0.97, 'Suburban': 1},
#  'insurance_hist': {'No coverage': 1.2,
#   'Coverage (past 6 months)': 1.05,
#   'Coverage (past 1 year)': 1.05},
#  'annual_mileage': {'0-7500 miles': 1,
#   '7500-10000 miles': 1.1,
#   '10001-15000 miles': 1.15,
#   '15000+ miles': 1.2},
#  'marital_status': {'Married': 0.95, 'Single/Divorced/Widowed': 1},
#  'claims_hist': {'Filed within last 1 year': 1.25,
#   'Filed within last 1-3 years': 1.15,
#   'No claims filed': 1},
# ...
